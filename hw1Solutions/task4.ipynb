# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %%
X_train[:,0]
# Out:
# array([ 5.9,  5.8,  6.8,  4.7,  6.9,  5. ,  5.4,  5. ,  6.5,  6.7,  6. ,
#         6.7,  5.6,  7.7,  6.3,  5.5,  6.3,  6.3,  4.9,  6.3,  7. ,  6.5,
#         6. ,  4.8,  5.8,  5.6,  5.6,  5.5,  6.1,  7.2,  5.3,  4.3,  6.4,
#         5.7,  5.4,  5.7,  6.9,  4.6,  5.9,  5.1,  4.6,  6.2,  7.2,  5.7,
#         4.8,  7.1,  6.9,  6.5,  6.4,  5.1,  4.8,  6.5,  6.7,  4.5,  6.2,
#         4.9,  5.7,  6.9,  4.4,  5. ,  7.2,  5.1,  4.4,  5.4,  5.5,  6.8,
#         7.6,  5.1,  4.9,  5.2,  5.7,  6.6,  5. ,  5.1,  6.4,  5.4,  7.7,
#         4.9,  7.9,  6.7,  5.2,  6. ,  5.8,  7.7,  5.1,  4.7,  7.4,  5. ,
#         6.3,  5.7,  5.8,  5.7,  6.4,  6.7,  6.3,  6.7,  5. ,  5.5,  6.7,
#         5.8,  5.1,  6.6,  5.6,  5.9,  6.3,  5.5,  5.1,  4.9,  6.3,  5.8,
#         7.7,  4.6])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
iris_dataset['data'], iris_dataset['target'], random_state=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
#Create the pair plot for the iris dataset using numpy and matplotlib
# Four axes, returned as a 2-d array
f, ax = plt.subplots(4, 4)

for i in range(0,4):
    ax[i,0].set_ylabel(iris_dataset.feature_names[i])
    
    for j in range(0,4): 
        if i==j:
            #histogram
            ax[i,j].hist(X_train[:,i])
        else:
            ax[i,j].scatter(X_train[:,i],X_train[:,j],c=y_train)
            ax[i,j].set_xticks([])
            ax[i,j].set_yticks([])

# %%
iris_dataset.feature_names[1]
# Out:
# 'sepal width (cm)'

# %%
type(f)
# Out:
# matplotlib.figure.Figure
